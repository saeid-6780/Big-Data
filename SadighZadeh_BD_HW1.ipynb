# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q https://dlcdn.apache.org/spark/spark-3.1.3/spark-3.1.3-bin-hadoop3.2.tgz

# %%
# !tar xf spark-3.1.3-bin-hadoop3.2.tgz

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.3-bin-hadoop3.2"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

#spark = SparkSession.builder\
#        .master("local")\
#        .appName("Colab")\
#        .config('spark.ui.port', '4050')\
#        .getOrCreate()
#spark

# %%
from pyspark.sql import Row
from pyspark.context import SparkContext
from pyspark.sql.context import SQLContext
from pyspark.sql.functions import col, substring, concat_ws,lit
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.types import *

sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
club_teams = spark.createDataFrame([
    Row(club='Man. City'),
    Row(club='Liverpool'),
    Row(club='Bayern Munich'),
    Row(club='Ajax'),
    Row(club='Chelsea'),
    Row(club='Real Madrid'),
    Row(club='PSG'),
    Row(club='Inter Milan'),
    Row(club='Barcelona'),
    Row(club='RB Leipzig'),
    Row(club='Arsenal'),
    Row(club='Dortmund'),
    Row(club='Villarreal'),
    Row(club='Atlético Madrid'),
    Row(club='Porto'),
    Row(club='Man. United'),
    Row(club='Tottenham'),
    Row(club='Leverkusen'),
    Row(club='Napoli'),
    Row(club='Atalanta'),
    Row(club='Athletic Bilbao'),
    Row(club='RB Salzburg'),
    Row(club='Juventus'),
    Row(club='Benfica'),
    Row(club='Sevilla'),
    Row(club='AC Milan'),
    Row(club='Brighton'),
    Row(club='Real Betis'),
    Row(club='Sporting'),
    Row(club='Monaco'),
    Row(club='Wolves'),
    Row(club='Hoffenheim'),
    Row(club='West Ham'),
    Row(club='Celta Vigo'),
    Row(club='Real Sociedad'),
    Row(club='Aston Villa'),
    Row(club='Mainz'),
    Row(club='Feyenoord'),
    Row(club='Rennes'),
    Row(club='Southampton'),
    Row(club='PSV'),
    Row(club='Lazio'),
    Row(club='Zenit'),
    Row(club='Roma'),
    Row(club='Crystal Palace'),
    Row(club='Lyon'),
    Row(club='Osasuna'),
    Row(club='Leicester'),
    Row(club='SC Freiburg'),
    Row(club='Fiorentina'),
])
club_teams_rdd=club_teams.rdd
club_teams_rdd.collect()
# Out:
# [Row(club='Man. City'),
#  Row(club='Liverpool'),
#  Row(club='Bayern Munich'),
#  Row(club='Ajax'),
#  Row(club='Chelsea'),
#  Row(club='Real Madrid'),
#  Row(club='PSG'),
#  Row(club='Inter Milan'),
#  Row(club='Barcelona'),
#  Row(club='RB Leipzig'),
#  Row(club='Arsenal'),
#  Row(club='Dortmund'),
#  Row(club='Villarreal'),
#  Row(club='Atlético Madrid'),
#  Row(club='Porto'),
#  Row(club='Man. United'),
#  Row(club='Tottenham'),
#  Row(club='Leverkusen'),
#  Row(club='Napoli'),
#  Row(club='Atalanta'),
#  Row(club='Athletic Bilbao'),
#  Row(club='RB Salzburg'),
#  Row(club='Juventus'),
#  Row(club='Benfica'),
#  Row(club='Sevilla'),
#  Row(club='AC Milan'),
#  Row(club='Brighton'),
#  Row(club='Real Betis'),
#  Row(club='Sporting'),
#  Row(club='Monaco'),
#  Row(club='Wolves'),
#  Row(club='Hoffenheim'),
#  Row(club='West Ham'),
#  Row(club='Celta Vigo'),
#  Row(club='Real Sociedad'),
#  Row(club='Aston Villa'),
#  Row(club='Mainz'),
#  Row(club='Feyenoord'),
# ...

# %%
club_teams_rdd.zipWithIndex().filter(lambda x: x[1] == 19).map(lambda x: x[0]).collect()

club_teams_rdd.map(lambda x: x[0].upper()).collect()
# Out:
# ['MAN. CITY',
#  'LIVERPOOL',
#  'BAYERN MUNICH',
#  'AJAX',
#  'CHELSEA',
#  'REAL MADRID',
#  'PSG',
#  'INTER MILAN',
#  'BARCELONA',
#  'RB LEIPZIG',
#  'ARSENAL',
#  'DORTMUND',
#  'VILLARREAL',
#  'ATLÉTICO MADRID',
#  'PORTO',
#  'MAN. UNITED',
#  'TOTTENHAM',
#  'LEVERKUSEN',
#  'NAPOLI',
#  'ATALANTA',
#  'ATHLETIC BILBAO',
#  'RB SALZBURG',
#  'JUVENTUS',
#  'BENFICA',
#  'SEVILLA',
#  'AC MILAN',
#  'BRIGHTON',
#  'REAL BETIS',
#  'SPORTING',
#  'MONACO',
#  'WOLVES',
#  'HOFFENHEIM',
#  'WEST HAM',
#  'CELTA VIGO',
#  'REAL SOCIEDAD',
#  'ASTON VILLA',
#  'MAINZ',
#  'FEYENOORD',
#  'RENNES',
#  'SOUTHAMPTON',
#  'PSV',
#  'LAZIO',
#  'ZENIT',
#  'ROMA',
#  'CRYSTAL PALACE',
#  'LYON',
#  'OSASUNA',
#  'LEICESTER',
#  'SC FREIBURG',
#  'FIORENTINA']

# %%
club_teams_rdd2=club_teams.withColumn('first_char', substring('club', 1,1)).rdd
club_teams_rdd2.map(lambda x: (x[1],x[0])).groupByKey().mapValues(list).collect()
# Out:
# [('M', ['Man. City', 'Man. United', 'Monaco', 'Mainz']),
#  ('L', ['Liverpool', 'Leverkusen', 'Lazio', 'Lyon', 'Leicester']),
#  ('B', ['Bayern Munich', 'Barcelona', 'Benfica', 'Brighton']),
#  ('A',
#   ['Ajax',
#    'Arsenal',
#    'Atlético Madrid',
#    'Atalanta',
#    'Athletic Bilbao',
#    'AC Milan',
#    'Aston Villa']),
#  ('C', ['Chelsea', 'Celta Vigo', 'Crystal Palace']),
#  ('R',
#   ['Real Madrid',
#    'RB Leipzig',
#    'RB Salzburg',
#    'Real Betis',
#    'Real Sociedad',
#    'Rennes',
#    'Roma']),
#  ('P', ['PSG', 'Porto', 'PSV']),
#  ('I', ['Inter Milan']),
#  ('D', ['Dortmund']),
#  ('V', ['Villarreal']),
#  ('T', ['Tottenham']),
#  ('N', ['Napoli']),
#  ('J', ['Juventus']),
#  ('S', ['Sevilla', 'Sporting', 'Southampton', 'SC Freiburg']),
#  ('W', ['Wolves', 'West Ham']),
#  ('H', ['Hoffenheim']),
#  ('F', ['Feyenoord', 'Fiorentina']),
#  ('Z', ['Zenit']),
#  ('O', ['Osasuna'])]

# %%
text_rdd = sc.textFile("/content/text-input.txt").flatMap(lambda line: line.split(" "))
text_rdd.map(lambda word: (word, 1)).reduceByKey(lambda a,b:a +b).collect()
# Out:
# [('Unlike', 1),
#  ('', 521),
#  ('professional', 2),
#  ('American', 2),
#  ('sports,', 2),
#  ('football', 8),
#  ('in', 17),
#  ('England—as', 1),
#  ('well', 1),
#  ('as', 5),
#  ('many', 1),
#  ('leagues', 1),
#  ('Europe', 1),
#  ('and', 40),
#  ('South', 1),
#  ('America—has', 1),
#  ('grave', 1),
#  ('outcomes', 1),
#  ('for', 7),
#  ('poorly', 1),
#  ('performing', 1),
#  ('clubs.', 2),
#  ('At', 1),
#  ('the', 60),
#  ('end', 1),
#  ('of', 35),
#  ('each', 4),
#  ('English', 5),
#  ('Premier', 5),
#  ('League', 5),
#  ('(EPL)', 1),
#  ('38-game', 1),
#  ('season,', 2),
#  ('top', 3),
#  ('clubs', 2),
#  ('get', 1),
#  ('rich(er),', 1),
#  ('while', 1),
#  ('bottom', 1),
#  ('three', 2),
#  ('are', 11),
#  ('relegated—unceremoniously', 1),
#  ('booted', 1),
#  ('out', 1),
#  ('league:', 1),
#  ('demoted', 1),
#  ('to', 21),
#  ('a', 14),
#  ('lower', 3),
#  ('division', 1),
#  ('euphemistically', 1),
#  ('called', 1),
#  ('Coca-Cola', 1),
#  ('Championship.1', 1),
# ...
